# %%
! python2 gradientDescent_multiCounty.py loadData debug
# Out:
# sys:1: DtypeWarning: Columns (22,24,28) have mixed types. Specify dtype option on import or set low_memory=False.
# Iteration 0
# Likelihood: -7976.82546026
# Intercept: 0
# Registered Dem: 0
# Registered Rep: 0
# Primary Dem: 0
# Primary Rep: 0
# Female: 0
# Male: 0
# Age: 0
# 2012 Voted Absentee: 0
# 2012 Voted In Person: 0
# 2014 Voted Absentee: 0
# 2014 Voted In Person: 0
# Apartment Dweller: 0
# County White Percent: 0
# County Black Percent: 0
# County Latino Percent: 0
# County College Educated Percent: 0
# County Population Density: 0
# County Income: 0
# Test error: 1.23283135936
# Test error: 20.0946408467
# /home/genocide1230/cs229/project/cs229-final/utilities.py:364: RuntimeWarning: overflow encountered in exp
#   probabilities = 1/(1 + np.exp(-designMatrix.dot(parameterValues)))
# Test error: 29.5981083575
# gradientDescent_multiCounty.py:138: RuntimeWarning: invalid value encountered in divide
#   axis = 0)/sigmaSq
# ...
